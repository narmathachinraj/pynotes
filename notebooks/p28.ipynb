# %%
num = int(input("Enter number: "))
rev = int(str(num)[::-1])
print(rev)
# Out:
# Enter number:  0
# 0

# %%
num = int(input("Enter number: "))
print(len(str(num)))
# Out:
# Enter number:  5
# 1

# %%
num = int(input("Enter number: "))
sum = 0
temp = num
while temp > 0:
    digit = temp % 10
    sum += digit**3
    temp //= 10

if num == sum:
    print("Armstrong")
else:
    print("Not Armstrong")
# Out:
# Enter number:  4
# Not Armstrong
