# %%
a = int(input())
b = int(input())
c = int(input())

avg = (a + b + c) / 3
print("Average =", avg)
# Out:
#  9
#  4
#  5
# Average = 6.0

# %%
num = int(input("Enter number: "))
temp = num
sum = 0

while temp > 0:
    digit = temp % 10
    sum += digit ** 3
    temp //= 10

if num == sum:
    print("Armstrong")
else:
    print("Not Armstrong")
# Out:
# Enter number:  8
# Not Armstrong

# %%
nums = [10, 5, 8, 2, 15]

nums.sort()
print("Second smallest:", nums[1])
# Out:
# Second smallest: 5
