# %%
nums = [1, 2, 3, 4]
count = 0

for i in nums:
    count += 1

print("Length:", count)
# Out:
# Length: 4

# %%
num = int(input("Enter number: "))
original = num
rev = 0

while num > 0:
    rev = rev * 10 + num % 10
    num //= 10

if original == rev:
    print("Palindrome")
else:
    print("Not palindrome")
# Out:
# Enter number:  4
# Palindrome

# %%
d1 = {"a": 1, "b": 2}
d2 = {"c": 3, "d": 4}

d1.update(d2)
print(d1)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
