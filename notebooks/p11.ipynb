# %%
nums = [1, 2, 3, 4, 5, 6]
even = 0
odd = 0

for i in nums:
    if i % 2 == 0:
        even += 1
    else:
        odd += 1

print("Even:", even)
print("Odd:", odd)
# Out:
# Even: 3
# Odd: 3

# %%
nums = [10, 25, 5, 40, 15]
print("Max =", max(nums))
# Out:
# Max = 40

# %%
nums = [1, 2, 3, 4]
nums.remove(3)
print(nums)
# Out:
# [1, 2, 4]
