# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a = 5
b = 3
print("Sum:", a + b)
# Out:
# Sum: 8

# %%
num = int(input("Enter number: "))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter number:  6
# Even
