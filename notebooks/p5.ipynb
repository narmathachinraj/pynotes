# %%
num = int(input("Enter number: "))
print("Square =", num * num)
# Out:
# Enter number:  5
# Square = 25

# %%
for i in range(5):
    print("Narmatha")
# Out:
# Narmatha
# Narmatha
# Narmatha
# Narmatha
# Narmatha

# %%
a = int(input("Enter first: "))
b = int(input("Enter second: "))

if a > b:
    print("A is largest")
else:
    print("B is largest")
# Out:
# Enter first:  5
# Enter second:  3
# A is largest
