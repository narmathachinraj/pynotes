# %%
year = int(input("Enter year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not Leap Year")
# Out:
# Enter year:  1984
# Leap Year

# %%
a = int(input())
b = int(input())
lcm = (a*b)//__import__('math').gcd(a, b)
print(lcm)
# Out:
#  5
#  3
# 15

# %%
import math
a = int(input())
b = int(input())
print(math.gcd(a, b))
# Out:
#  7
#  4
# 1
