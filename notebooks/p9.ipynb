# %%
a = int(input("Enter first: "))
b = int(input("Enter second: "))

a, b = b, a

print("a =", a)
print("b =", b)
# Out:
# Enter first:  23
# Enter second:  12
# a = 12
# b = 23

# %%
num = int(input("Enter number: "))
print("Cube =", num ** 3)
# Out:
# Enter number:  5
# Cube = 125

# %%
num = int(input("Enter number: "))
if num % 7 == 0:
    print("Divisible by 7")
else:
    print("Not divisible")
# Out:
# Enter number:  3
# Not divisible
