# %%
# Taking input from user
a = int(input())

# Printing the number
print("Given number:", a)

# Printing unit digit
print("unit digit:", a % 10)
# Out:
#  23
# Given number: 23
# unit digit: 3

# %%
def show_number():
    a = 10
    print(a)

show_number()
# Out:
# 10

# %%
# Taking input
n = int(input())

# Checking the number
if n > 0:
    print("positive")
elif n < 0:
    print("Negative")
else:
    print("Zero")
# Out:
#  65
# positive
