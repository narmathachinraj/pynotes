# %%
nums = [1, 2, 2, 3]
print(list(set(nums)))
# Out:
# [1, 2, 3]

# %%
nums = [1, 2, 3, 4]
print("Sum:", sum(nums))
# Out:
# Sum: 10

# %%
nums = [3, 7, 2, 9]
print("Min:", min(nums))
# Out:
# Min: 2
